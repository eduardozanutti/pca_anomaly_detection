# %% [markdown]
# # PCA Anomaly Detection - TEP
#
# Notebook inicial para explorar a base Tennessee Eastman Process e validar o pipeline de deteccao de anomalias com PCA.

# %%
from pathlib import Path

import pandas as pd
from sklearn.preprocessing import StandardScaler

from pca_anomaly_detection.models.pca_detector import PCAAnomalyDetector

# %%
# Ajuste os caminhos conforme os arquivos reais
train_path = Path('..') / 'data' / 'raw' / 'train_normal.csv'
test_path = Path('..') / 'data' / 'raw' / 'test_fault.csv'

print('train_path:', train_path)
print('test_path:', test_path)
